# %% [markdown]
# ## Background
#
#
#
# Social Media's presence is ubiquitous today.
#
# Now more than ever, politicians turn to Twitter over other Social Media platforms.
#
# Currently, Narendra Modi, the Prime Minister of India, is the most followed world leader with over 64 million followers on his personal Twitter.
#
# Twitter is used by politicians including various heads of state, cabinet members, and other politicians in India. These politicians use the platform to self-promote and to communicate with their constituents.

# %% [markdown]
# ## Purpose
#
# Popularity on Twitter is positively associated to political positions characterized by a rich-get-richer effect. Influence on Twitter is positively associated with both the degree of interactive usage and the level of popularity. A network analysis of the politicians's of India has been carried on to know they impact each other.

# %% [markdown]
# ### Problem Statement
# To understand how the politicians of India impact each others using Social network Analysis.
#
# ### Objectives
# To find the most Influential, Popular, Important politicians and the politicians who act as a bridge between the politicians in twitter.

# %%
# libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tsma.csv")

# %%
df
# Out:
#               Source          Target
# 0     HemantSorenJMM        AmitShah
# 1       SangmaConrad        AmitShah
# 2       rajnathsingh        AmitShah
# 3    jairamthakurbjp        AmitShah
# 4             BSYBJP        AmitShah
# ..               ...             ...
# 319    VNarayanasami  MamataOfficial
# 320     SangmaConrad  MamataOfficial
# 321     rajnathsingh  MamataOfficial
# 322  jairamthakurbjp  MamataOfficial
# 323     narendramodi  MamataOfficial
#
# [324 rows x 2 columns]

# %%
G_pol=nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph() )

# %%
print(nx.info(G_pol))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 32
# Number of edges: 323
# Average in degree:  10.0938
# Average out degree:  10.0938

# %%
plt.figure(figsize=(15,10))
nx.draw_random(G_pol, with_labels=True, node_size=500, node_color='g', alpha=0.3, arrows=True)
plt.show()

# %%
plt.figure(figsize=(15,10))
nx.draw_circular(G_pol, with_labels=True, node_size=500, node_color='violet', alpha=0.6, arrows=True)
plt.show()

# %%
# General Connections
nx.degree(G_pol)
# Out:
# DiDegreeView({'HemantSorenJMM': 13, 'AmitShah': 17, 'SangmaConrad': 40, 'rajnathsingh': 47, 'jairamthakurbjp': 37, 'BSYBJP': 21, 'narendramodi': 47, 'OfficeofUT': 1, 'ZoramthangaCM': 17, 'GolayPs': 8, 'NBirenSingh': 33, 'Neiphiu_Rio': 20, 'DrPramodPSawant': 24, 'PemaKhanduBJP': 30, 'bhupeshbaghel': 13, 'BjpBiplab': 25, 'myogiadityanath': 17, 'ysjagan': 8, 'sarbanandsonwal': 25, 'tsrawatbjp': 28, 'ChouhanShivraj': 34, 'vijayrupanibjp': 22, 'mlkhattar': 29, 'capt_amarinder': 10, 'NitishKumar': 11, 'nsitharaman': 22, 'MamataOfficial': 11, 'ashokgehlot51': 11, 'VNarayanasami': 10, 'ArvindKejriwal': 5, 'vijayanpinarayi': 2, 'Naveen_Odisha': 8})

# %%
# Degree of Connection 
nx.degree(G_pol,"AmitShah")
# Out:
# 17

# %% [markdown]
# #### To know to Followers count

# %%
G_pol.in_degree("AmitShah")
# Out:
# 6

# %%
in_degree = G_pol.in_degree() 
in_values = sorted(in_degree)
in_values
# Out:
# [('AmitShah', 6),
#  ('ArvindKejriwal', 5),
#  ('BSYBJP', 11),
#  ('BjpBiplab', 13),
#  ('ChouhanShivraj', 19),
#  ('DrPramodPSawant', 8),
#  ('GolayPs', 0),
#  ('HemantSorenJMM', 4),
#  ('MamataOfficial', 7),
#  ('NBirenSingh', 13),
#  ('Naveen_Odisha', 8),
#  ('Neiphiu_Rio', 11),
#  ('NitishKumar', 10),
#  ('OfficeofUT', 0),
#  ('PemaKhanduBJP', 13),
#  ('SangmaConrad', 13),
#  ('VNarayanasami', 4),
#  ('ZoramthangaCM', 8),
#  ('ashokgehlot51', 6),
#  ('bhupeshbaghel', 7),
#  ('capt_amarinder', 7),
#  ('jairamthakurbjp', 13),
#  ('mlkhattar', 14),
#  ('myogiadityanath', 14),
#  ('narendramodi', 24),
#  ('nsitharaman', 16),
#  ('rajnathsingh', 22),
#  ('sarbanandsonwal', 16),
#  ('tsrawatbjp', 11),
#  ('vijayanpinarayi', 2),
#  ('vijayrupanibjp', 13),
#  ('ysjagan', 5)]

# %% [markdown]
# ##### Shri Shivraj Singh Chouhan, the Chief minister of Madhya Pradesh followed by Shri Sarbananda Sonowal, the Chief minister of Assam are the most followed amoung the  Chief ministers

# %% [markdown]
# #### To know to Following count

# %%
out_degree = G_pol.out_degree() 
out_values = sorted(out_degree)
out_values
# Out:
# [('AmitShah', 11),
#  ('ArvindKejriwal', 0),
#  ('BSYBJP', 10),
#  ('BjpBiplab', 12),
#  ('ChouhanShivraj', 15),
#  ('DrPramodPSawant', 16),
#  ('GolayPs', 8),
#  ('HemantSorenJMM', 9),
#  ('MamataOfficial', 4),
#  ('NBirenSingh', 20),
#  ('Naveen_Odisha', 0),
#  ('Neiphiu_Rio', 9),
#  ('NitishKumar', 1),
#  ('OfficeofUT', 1),
#  ('PemaKhanduBJP', 17),
#  ('SangmaConrad', 27),
#  ('VNarayanasami', 6),
#  ('ZoramthangaCM', 9),
#  ('ashokgehlot51', 5),
#  ('bhupeshbaghel', 6),
#  ('capt_amarinder', 3),
#  ('jairamthakurbjp', 24),
#  ('mlkhattar', 15),
#  ('myogiadityanath', 3),
#  ('narendramodi', 23),
#  ('nsitharaman', 6),
#  ('rajnathsingh', 25),
#  ('sarbanandsonwal', 9),
#  ('tsrawatbjp', 17),
#  ('vijayanpinarayi', 0),
#  ('vijayrupanibjp', 9),
#  ('ysjagan', 3)]

# %% [markdown]
# #####  Shri Conrad Kongkal Sangma, the Chief minister of Meghalaya followed by Shri Jairam Thakur, the Chief minister of Himachal Pradesh are the following most of the other politicians in the group

# %% [markdown]
# #### Degree Centrality
#
# Number of links held by each node. Simplest measure of node connectivity.
#
# Used for finding very connected individuals, popular individuals, individuals who are likely to hold most information or individuals who can quickly connect with the wider network.

# %%
most_popular = nx.degree_centrality(G_pol)

for w in sorted(most_popular, key=most_popular.get, reverse=True):
    print(w, most_popular[w])
# Out:
# rajnathsingh 1.5161290322580645
# narendramodi 1.5161290322580645
# SangmaConrad 1.2903225806451613
# jairamthakurbjp 1.1935483870967742
# ChouhanShivraj 1.096774193548387
# NBirenSingh 1.064516129032258
# PemaKhanduBJP 0.967741935483871
# mlkhattar 0.9354838709677419
# tsrawatbjp 0.9032258064516129
# BjpBiplab 0.8064516129032258
# sarbanandsonwal 0.8064516129032258
# DrPramodPSawant 0.7741935483870968
# vijayrupanibjp 0.7096774193548387
# nsitharaman 0.7096774193548387
# BSYBJP 0.6774193548387096
# Neiphiu_Rio 0.6451612903225806
# AmitShah 0.5483870967741935
# ZoramthangaCM 0.5483870967741935
# myogiadityanath 0.5483870967741935
# HemantSorenJMM 0.4193548387096774
# bhupeshbaghel 0.4193548387096774
# NitishKumar 0.3548387096774194
# MamataOfficial 0.3548387096774194
# ashokgehlot51 0.3548387096774194
# capt_amarinder 0.3225806451612903
# VNarayanasami 0.3225806451612903
# GolayPs 0.25806451612903225
# ysjagan 0.25806451612903225
# Naveen_Odisha 0.25806451612903225
# ArvindKejriwal 0.16129032258064516
# vijayanpinarayi 0.06451612903225806
# OfficeofUT 0.03225806451612903

# %% [markdown]
# ##### Shri Conrad Kongkal Sangma, the Chief minister of Meghalaya followed by Shri Jairam Thakur,  the Chief minister of Himachal Pradesh are the most popular amoung the Chief ministers

# %% [markdown]
# #### EigenVector Centrality <br>
#
# It decides that a node is important if it is connected to other important nodes.

# %%
most_important = nx.eigenvector_centrality(G_pol)

for w in sorted(most_important, key=most_important.get, reverse=True):
    print(w, most_important[w])
# Out:
# narendramodi 0.31504686447256275
# rajnathsingh 0.30511630910549237
# ChouhanShivraj 0.28308232688822227
# nsitharaman 0.25717545449493384
# sarbanandsonwal 0.25482917671472993
# mlkhattar 0.23644763971641455
# NBirenSingh 0.2190539276356406
# BjpBiplab 0.21905392763564058
# vijayrupanibjp 0.2182232929036882
# jairamthakurbjp 0.2152867996472651
# myogiadityanath 0.21327661271683582
# SangmaConrad 0.20099586535882522
# PemaKhanduBJP 0.20099586535882522
# tsrawatbjp 0.19440553966273547
# BSYBJP 0.1899030969635952
# Neiphiu_Rio 0.18424036434286103
# NitishKumar 0.15542112376748488
# DrPramodPSawant 0.14938112132656817
# ZoramthangaCM 0.1132759844172749
# Naveen_Odisha 0.10928274871394447
# AmitShah 0.09672016258772864
# MamataOfficial 0.09404272186034549
# capt_amarinder 0.07875554000204661
# ysjagan 0.07344946918010671
# bhupeshbaghel 0.07168610480840881
# ArvindKejriwal 0.05766010701311869
# ashokgehlot51 0.05643014326746794
# HemantSorenJMM 0.04180794269279229
# VNarayanasami 0.04152066099052591
# vijayanpinarayi 0.018518261618859604
# OfficeofUT 6.51455332830826e-13
# GolayPs 6.51455332830826e-13

# %% [markdown]
# ##### Shri Shivraj Singh Chouhan, the Chief minister of Madhya Pradesh followed by Shri Sarbananda Sonowal, the Chief minister of Assam are the most important amoung the  Chief ministers

# %% [markdown]
# #### PageRank
#
# PageRank is a variant of EigenCentrality, also assigning nodes a score based on their connections, and their connections’ connections. The difference is that PageRank also takes link direction and weight into account – so links can only pass influence in one direction, and pass different amounts of influence.
#
# This measure uncovers nodes whose influence extends beyond their direct connections into the wider network.
#
# Fun Fact: PageRank is famously one of the ranking algorithms behind the original Google search engine.

# %%
pagerank = nx.pagerank(G_pol, alpha=0.9)
for w in sorted(pagerank, key=pagerank.get, reverse=True):
    print(w, pagerank[w])
# Out:
# narendramodi 0.10697435117721907
# rajnathsingh 0.07454359171903072
# ChouhanShivraj 0.06133439956121856
# nsitharaman 0.04647866663349745
# mlkhattar 0.043445833937147425
# sarbanandsonwal 0.0420163115200373
# NBirenSingh 0.036294148648531345
# myogiadityanath 0.035904983415147675
# BSYBJP 0.03580350972126107
# jairamthakurbjp 0.03578994636468745
# vijayrupanibjp 0.03552809343213156
# BjpBiplab 0.035281304883239446
# tsrawatbjp 0.034571223075385765
# SangmaConrad 0.03312577153025188
# PemaKhanduBJP 0.03250891331353435
# NitishKumar 0.030020262788589706
# Neiphiu_Rio 0.028290127868926897
# bhupeshbaghel 0.024639245768663987
# capt_amarinder 0.023983711349951278
# DrPramodPSawant 0.02347733186001583
# Naveen_Odisha 0.023459180920652235
# ashokgehlot51 0.022875412476982646
# MamataOfficial 0.019173782473252608
# AmitShah 0.018522663123981944
# ArvindKejriwal 0.01767246171553446
# ZoramthangaCM 0.01662023427201326
# ysjagan 0.015839117289056924
# HemantSorenJMM 0.015032644769605837
# VNarayanasami 0.014741538588084717
# vijayanpinarayi 0.007088770974000621
# OfficeofUT 0.0044812324141828945
# GolayPs 0.0044812324141828945

# %% [markdown]
# ##### Shri Shivraj Singh Chouhan, the Chief minister of Madhya Pradesh followed by Shri Manohar Lal, the Chief minister of Haryana are the most important amoung the  Chief ministers

# %% [markdown]
# #### Short Path

# %%
nx.shortest_path(G_pol,"NitishKumar","NBirenSingh")
# Out:
# ['NitishKumar', 'narendramodi', 'NBirenSingh']

# %%
nx.shortest_path(G_pol,"NitishKumar","HemantSorenJMM")
# Out:
# ['NitishKumar', 'narendramodi', 'NBirenSingh', 'HemantSorenJMM']

# %%
nx.shortest_path(G_pol,"HemantSorenJMM","VNarayanasami")
# Out:
# ['HemantSorenJMM', 'bhupeshbaghel', 'VNarayanasami']

# %%
# Returns shortest path length between each node
list(nx.all_pairs_shortest_path_length(G_pol))
# Out:
# [('HemantSorenJMM',
#   {'HemantSorenJMM': 0,
#    'AmitShah': 1,
#    'ysjagan': 1,
#    'bhupeshbaghel': 1,
#    'ArvindKejriwal': 1,
#    'vijayanpinarayi': 1,
#    'Naveen_Odisha': 1,
#    'capt_amarinder': 1,
#    'ashokgehlot51': 1,
#    'MamataOfficial': 1,
#    'narendramodi': 2,
#    'nsitharaman': 2,
#    'rajnathsingh': 2,
#    'sarbanandsonwal': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'VNarayanasami': 2,
#    'NitishKumar': 2,
#    'DrPramodPSawant': 3,
#    'NBirenSingh': 3,
#    'SangmaConrad': 3,
#    'PemaKhanduBJP': 3,
#    'Neiphiu_Rio': 3,
#    'BjpBiplab': 3,
#    'ZoramthangaCM': 3}),
#  ('AmitShah',
#   {'AmitShah': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('SangmaConrad',
#   {'SangmaConrad': 0,
#    'AmitShah': 1,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'ysjagan': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'bhupeshbaghel': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'HemantSorenJMM': 1,
#    'vijayanpinarayi': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'Naveen_Odisha': 1,
#    'VNarayanasami': 1,
#    'capt_amarinder': 1,
#    'ashokgehlot51': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'MamataOfficial': 1,
#    'BSYBJP': 2,
#    'ArvindKejriwal': 2}),
#  ('rajnathsingh',
#   {'rajnathsingh': 0,
#    'AmitShah': 1,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'bhupeshbaghel': 1,
#    'ArvindKejriwal': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'Naveen_Odisha': 1,
#    'capt_amarinder': 1,
#    'ashokgehlot51': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'MamataOfficial': 1,
#    'ysjagan': 2,
#    'HemantSorenJMM': 2,
#    'VNarayanasami': 2,
#    'vijayanpinarayi': 2}),
#  ('jairamthakurbjp',
#   {'jairamthakurbjp': 0,
#    'AmitShah': 1,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'ysjagan': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'bhupeshbaghel': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'Naveen_Odisha': 1,
#    'VNarayanasami': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'MamataOfficial': 1,
#    'ArvindKejriwal': 2,
#    'capt_amarinder': 2,
#    'ashokgehlot51': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('BSYBJP',
#   {'BSYBJP': 0,
#    'AmitShah': 1,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'ysjagan': 1,
#    'sarbanandsonwal': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'ChouhanShivraj': 1,
#    'myogiadityanath': 1,
#    'jairamthakurbjp': 2,
#    'tsrawatbjp': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 3,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('narendramodi',
#   {'narendramodi': 0,
#    'AmitShah': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'ysjagan': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'ArvindKejriwal': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'Naveen_Odisha': 1,
#    'capt_amarinder': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'MamataOfficial': 1,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('OfficeofUT',
#   {'OfficeofUT': 0,
#    'narendramodi': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'rajnathsingh': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 3,
#    'ZoramthangaCM': 3,
#    'ashokgehlot51': 3,
#    'VNarayanasami': 3,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('ZoramthangaCM',
#   {'ZoramthangaCM': 0,
#    'narendramodi': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'BjpBiplab': 1,
#    'MamataOfficial': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'bhupeshbaghel': 2,
#    'ashokgehlot51': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2,
#    'VNarayanasami': 2}),
#  ('GolayPs',
#   {'GolayPs': 0,
#    'narendramodi': 1,
#    'rajnathsingh': 1,
#    'ArvindKejriwal': 1,
#    'ChouhanShivraj': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'myogiadityanath': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'NBirenSingh': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ashokgehlot51': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2,
#    'VNarayanasami': 2}),
#  ('NBirenSingh',
#   {'NBirenSingh': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'HemantSorenJMM': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'Naveen_Odisha': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'ArvindKejriwal': 2,
#    'capt_amarinder': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'vijayanpinarayi': 2}),
#  ('Neiphiu_Rio',
#   {'Neiphiu_Rio': 0,
#    'narendramodi': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'jairamthakurbjp': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'PemaKhanduBJP': 1,
#    'BjpBiplab': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'BSYBJP': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('DrPramodPSawant',
#   {'DrPramodPSawant': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('PemaKhanduBJP',
#   {'PemaKhanduBJP': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'Neiphiu_Rio': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'ArvindKejriwal': 2,
#    'BSYBJP': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('bhupeshbaghel',
#   {'bhupeshbaghel': 0,
#    'narendramodi': 1,
#    'rajnathsingh': 1,
#    'HemantSorenJMM': 1,
#    'VNarayanasami': 1,
#    'capt_amarinder': 1,
#    'ashokgehlot51': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'ZoramthangaCM': 2,
#    'vijayanpinarayi': 2}),
#  ('BjpBiplab',
#   {'BjpBiplab': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'DrPramodPSawant': 1,
#    'jairamthakurbjp': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'tsrawatbjp': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'BSYBJP': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'myogiadityanath': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('myogiadityanath',
#   {'myogiadityanath': 0,
#    'narendramodi': 1,
#    'rajnathsingh': 1,
#    'ChouhanShivraj': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 3,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('ysjagan',
#   {'ysjagan': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'AmitShah': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 3,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('sarbanandsonwal',
#   {'sarbanandsonwal': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'HemantSorenJMM': 2,
#    'VNarayanasami': 3,
#    'vijayanpinarayi': 3}),
#  ('tsrawatbjp',
#   {'tsrawatbjp': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'ZoramthangaCM': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('ChouhanShivraj',
#   {'ChouhanShivraj': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'DrPramodPSawant': 1,
#    'vijayrupanibjp': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'PemaKhanduBJP': 1,
#    'Neiphiu_Rio': 1,
#    'BjpBiplab': 1,
#    'tsrawatbjp': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'myogiadityanath': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('vijayrupanibjp',
#   {'vijayrupanibjp': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'mlkhattar': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'myogiadityanath': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('mlkhattar',
#   {'mlkhattar': 0,
#    'narendramodi': 1,
#    'nsitharaman': 1,
#    'rajnathsingh': 1,
#    'sarbanandsonwal': 1,
#    'NitishKumar': 1,
#    'vijayrupanibjp': 1,
#    'jairamthakurbjp': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'NBirenSingh': 1,
#    'SangmaConrad': 1,
#    'PemaKhanduBJP': 1,
#    'BjpBiplab': 1,
#    'myogiadityanath': 1,
#    'tsrawatbjp': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 2,
#    'HemantSorenJMM': 2,
#    'vijayanpinarayi': 2}),
#  ('capt_amarinder',
#   {'capt_amarinder': 0,
#    'narendramodi': 1,
#    'bhupeshbaghel': 1,
#    'ashokgehlot51': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'rajnathsingh': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'HemantSorenJMM': 2,
#    'VNarayanasami': 2,
#    'ZoramthangaCM': 3,
#    'vijayanpinarayi': 3}),
#  ('NitishKumar',
#   {'NitishKumar': 0,
#    'narendramodi': 1,
#    'AmitShah': 2,
#    'nsitharaman': 2,
#    'rajnathsingh': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 3,
#    'ZoramthangaCM': 3,
#    'ashokgehlot51': 3,
#    'VNarayanasami': 3,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('nsitharaman',
#   {'nsitharaman': 0,
#    'narendramodi': 1,
#    'rajnathsingh': 1,
#    'mlkhattar': 1,
#    'BSYBJP': 1,
#    'ChouhanShivraj': 1,
#    'tsrawatbjp': 1,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'sarbanandsonwal': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'jairamthakurbjp': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'Naveen_Odisha': 2,
#    'capt_amarinder': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'MamataOfficial': 2,
#    'bhupeshbaghel': 2,
#    'ZoramthangaCM': 2,
#    'ashokgehlot51': 2,
#    'VNarayanasami': 3,
#    'HemantSorenJMM': 3,
#    'vijayanpinarayi': 3}),
#  ('MamataOfficial',
#   {'MamataOfficial': 0,
#    'rajnathsingh': 1,
#    'NitishKumar': 1,
#    'ArvindKejriwal': 1,
#    'Naveen_Odisha': 1,
#    'AmitShah': 2,
#    'narendramodi': 2,
#    'nsitharaman': 2,
#    'sarbanandsonwal': 2,
#    'bhupeshbaghel': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'ChouhanShivraj': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'ZoramthangaCM': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'capt_amarinder': 2,
#    'ashokgehlot51': 2,
#    'BjpBiplab': 2,
#    'myogiadityanath': 2,
#    'tsrawatbjp': 2,
#    'ysjagan': 3,
#    'HemantSorenJMM': 3,
#    'VNarayanasami': 3,
#    'vijayanpinarayi': 3}),
#  ('ashokgehlot51',
#   {'ashokgehlot51': 0,
#    'NitishKumar': 1,
#    'bhupeshbaghel': 1,
#    'HemantSorenJMM': 1,
#    'VNarayanasami': 1,
#    'capt_amarinder': 1,
#    'narendramodi': 2,
#    'rajnathsingh': 2,
#    'AmitShah': 2,
#    'ysjagan': 2,
#    'ArvindKejriwal': 2,
#    'vijayanpinarayi': 2,
#    'Naveen_Odisha': 2,
#    'MamataOfficial': 2,
#    'ChouhanShivraj': 2,
#    'nsitharaman': 3,
#    'sarbanandsonwal': 3,
#    'DrPramodPSawant': 3,
#    'vijayrupanibjp': 3,
#    'mlkhattar': 3,
#    'jairamthakurbjp': 3,
#    'BSYBJP': 3,
#    'NBirenSingh': 3,
#    'SangmaConrad': 3,
#    'PemaKhanduBJP': 3,
#    'Neiphiu_Rio': 3,
#    'BjpBiplab': 3,
#    'myogiadityanath': 3,
#    'tsrawatbjp': 3,
#    'ZoramthangaCM': 3}),
#  ('VNarayanasami',
#   {'VNarayanasami': 0,
#    'bhupeshbaghel': 1,
#    'ChouhanShivraj': 1,
#    'Naveen_Odisha': 1,
#    'capt_amarinder': 1,
#    'ashokgehlot51': 1,
#    'MamataOfficial': 1,
#    'narendramodi': 2,
#    'rajnathsingh': 2,
#    'HemantSorenJMM': 2,
#    'nsitharaman': 2,
#    'sarbanandsonwal': 2,
#    'DrPramodPSawant': 2,
#    'vijayrupanibjp': 2,
#    'mlkhattar': 2,
#    'jairamthakurbjp': 2,
#    'BSYBJP': 2,
#    'NBirenSingh': 2,
#    'SangmaConrad': 2,
#    'PemaKhanduBJP': 2,
#    'Neiphiu_Rio': 2,
#    'BjpBiplab': 2,
#    'tsrawatbjp': 2,
#    'NitishKumar': 2,
#    'ArvindKejriwal': 2,
#    'AmitShah': 3,
#    'ysjagan': 3,
#    'myogiadityanath': 3,
#    'ZoramthangaCM': 3,
#    'vijayanpinarayi': 3}),
#  ('ArvindKejriwal', {'ArvindKejriwal': 0}),
#  ('vijayanpinarayi', {'vijayanpinarayi': 0}),
#  ('Naveen_Odisha', {'Naveen_Odisha': 0})]

# %% [markdown]
# #### Betweenness centrality
#
# It measures the number of times a node lies on the shortest path between other nodes.
#
# This measure shows which nodes are ‘bridges’ between nodes in a network.
# It does this by identifying all the shortest paths and then counting how many times each node falls on one.

# %%
best_connector = nx.betweenness_centrality(G_pol)
for w in sorted(best_connector, key=best_connector.get, reverse=True):
    print(w, best_connector[w])
# Out:
# narendramodi 0.17997750009846786
# rajnathsingh 0.14443439624891238
# SangmaConrad 0.07912572344023958
# ChouhanShivraj 0.0408306030886676
# jairamthakurbjp 0.03623274276500082
# NBirenSingh 0.021355451597387082
# bhupeshbaghel 0.018137450960031606
# AmitShah 0.015356883260109068
# HemantSorenJMM 0.014527300656332913
# mlkhattar 0.010106018533437887
# tsrawatbjp 0.00811677122160993
# PemaKhanduBJP 0.007618019674471287
# ashokgehlot51 0.007355641670157801
# capt_amarinder 0.006450919152532055
# VNarayanasami 0.006049667178699437
# BSYBJP 0.005657787552948843
# MamataOfficial 0.005171263921263922
# NitishKumar 0.00384536610343062
# sarbanandsonwal 0.0033520541585057716
# BjpBiplab 0.003076890254309609
# nsitharaman 0.002644300144300144
# ysjagan 0.00250792218534154
# DrPramodPSawant 0.0018431822060854318
# ZoramthangaCM 0.0018100358422939065
# vijayrupanibjp 0.0010098100823907276
# Neiphiu_Rio 0.0002880184331797235
# OfficeofUT 0.0
# GolayPs 0.0
# myogiadityanath 0.0
# ArvindKejriwal 0.0
# vijayanpinarayi 0.0
# Naveen_Odisha 0.0

# %% [markdown]
# ##### Shri Conrad Kongkal Sangma, the Chief minister of Meghalaya followed by Shri Shivraj Singh Chouhan, the Chief minister of Madhya Pradesh are acting as a bridge between the  Chief ministers

# %%
pos = nx.spring_layout(G_pol)
betCent = nx.betweenness_centrality(G_pol, normalized=True, endpoints=True)
node_color = [20000.0 * G_pol.degree(v) for v in G_pol]
node_size =  [v * 10000 for v in betCent.values()]
plt.figure(figsize=(8,8))
nx.draw_networkx(G_pol, pos=pos, with_labels=True,
                 node_color=node_color,
                 node_size=node_size)
plt.axis('off')
# Out:
# (-1.0490040471759134,
#  0.9932282658497619,
#  -1.2068266798517966,
#  1.2096984627913472)

# %% [markdown]
# #### Closeness centrality
#
# It scores each node based on their ‘closeness’ to all other nodes in the network.
#
# Used for finding the individuals who are best placed to influence the entire network most quickly.

# %%
most_influential  = nx.closeness_centrality(G_pol)
for w in sorted(most_influential , key=most_influential.get, reverse=True):
    print(w, most_influential [w])
# Out:
# narendramodi 0.7903225806451613
# rajnathsingh 0.7438330170777988
# ChouhanShivraj 0.6835222319093287
# sarbanandsonwal 0.6168371361132966
# nsitharaman 0.6168371361132966
# mlkhattar 0.5881470367591898
# jairamthakurbjp 0.5747800586510263
# myogiadityanath 0.5747800586510263
# vijayrupanibjp 0.5747800586510263
# SangmaConrad 0.5620071684587814
# NBirenSingh 0.5620071684587814
# PemaKhanduBJP 0.5620071684587814
# BjpBiplab 0.5620071684587814
# BSYBJP 0.5497896213183731
# tsrawatbjp 0.5497896213183731
# NitishKumar 0.5497896213183731
# Naveen_Odisha 0.5425806451612902
# Neiphiu_Rio 0.5380919698009609
# capt_amarinder 0.5161290322580645
# MamataOfficial 0.5161290322580645
# ArvindKejriwal 0.5118685331710285
# DrPramodPSawant 0.5058064516129033
# AmitShah 0.4958886780518659
# bhupeshbaghel 0.4958886780518659
# ashokgehlot51 0.48635235732009924
# ysjagan 0.4771758977480219
# ZoramthangaCM 0.4683393070489844
# VNarayanasami 0.421505376344086
# HemantSorenJMM 0.41459545214172394
# vijayanpinarayi 0.39895635673624286
# OfficeofUT 0.0
# GolayPs 0.0

# %% [markdown]
# ##### Shri Shivraj Singh Chouhan, the Chief minister of Madhya Pradesh followed by  Shri Sarbananda Sonowal, the Chief minister of Assam are the most influential amoung the  Chief ministers

# %% [markdown]
# #### Building A Subgroup
#
# Retrieve all the nodes connected to a given node within a NetworkX graph
#
# Method used : Breadth-first search

# %%
group1 = nx.bfs_tree(G_pol,"AmitShah")
group2 = nx.bfs_tree(G_pol,"rajnathsingh")
group3 = nx.bfs_tree(G_pol,"narendramodi")

# %%
plt.figure(figsize=(15,15))
nx.draw_networkx(group1, with_labels=True, node_color='pink', node_size=700, alpha=0.5, arrows=True)
plt.show()

# %%
plt.figure(figsize=(15,15))
nx.draw_networkx(group2, with_labels=True, node_color='yellow', node_size=700, alpha=0.5, arrows=True)
plt.show()

# %%
plt.figure(figsize=(15,15))
nx.draw_networkx(group3, with_labels=True, node_color='r', node_size=700, alpha=0.5, arrows=True)
plt.show()

# %% [markdown]
# #### Clustering
#
# It is observed that people who share connections in a social network tend to form associations.
#
# In other words, there is a tendency in a social network to form clusters.
#
# ##### Two types of Clustering <br>
# Local Clustering Coefficient <br>
# Global Clustering Coefficient <br>
#
# ##### Local Clustering Coefficient
#
# Fraction of pairs of the node's friends that are friends with each other.
#
# ##### Global Clustering
#
# Measures the Clustering of the whole network by measuring the overall Average local clustering coefficient of all nodes in a graph

# %%
# Local Clustering Coefficient 
print("Local Clustering Coefficient for narendramodi: ",nx.clustering(G_pol,'narendramodi'))
print("Local Clustering Coefficient for rajnathsingh: ",nx.clustering(G_pol,'rajnathsingh'))

# Global Clustering
print("Global clustering using Average clustering: ", nx.average_clustering(G_pol))
# Out:
# Local Clustering Coefficient for narendramodi:  0.42177191328934965
# Local Clustering Coefficient for rajnathsingh:  0.43355325164938735
# Global clustering using Average clustering:  0.6097686583809696

# %% [markdown]
# ### Recommendation and Conclution
#
# The politician will get to how they are scaled among other politicians in twitter. Who's thoughts and opinions are impacting whom and the social network expresses the hiddern relationship (like who supports whom) between the state leaders to the General public.
#
# This also provides valuable information about individual politicians (How much they influence others, Who are close to each other and Who acts as a bridge, How important they are and they shortest path for them to communicate)  in the network.
